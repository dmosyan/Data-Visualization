# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import seaborn as sns

# %%
df1 = pd.read_csv(r'C:\Users\dmosy\Desktop\ML\df1.csv', index_col=0)
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv(r'C:\Users\dmosy\Desktop\ML\df2.csv')
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df1['A'].hist(bins=30)

# %%
df1['A'].hist(bins=30) #after importing seaborn it will print like sns

# %%
df1['A'].plot(kind='hist', bins = 30)

# %%
df1['A'].plot.hist(bins=30)

# %%
df1.plot.line(x=df1.index, y=['B'], figsize=(12,3), lw=1)
# Out:
# C:\Users\dmosy\Conda3\lib\site-packages\pandas\plotting\_core.py:1716: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %%
df1.plot.scatter(x='A',y='B', c='C', cmap='coolwarm')

# %%
df1.plot.scatter(x='A',y='B', s=df1['C']*50)
# Out:
# C:\Users\dmosy\Conda3\lib\site-packages\matplotlib\collections.py:853: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
df2.plot.box()

# %%
df = pd.DataFrame(np.random.randn(1000,2), columns=['a','b'])

# %%
df.head()
# Out:
#           a         b
# 0 -0.550574 -0.846861
# 1  0.358774 -0.048298
# 2  0.783142  1.020242
# 3  0.063997 -0.488209
# 4 -0.772325 -0.347931

# %%
df.plot.hexbin(x='a',y='b', gridsize=10)

# %%
df2['a'].plot.kde()

# %%
df2.plot.density()

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df3 = pd.read_csv(r'C:\Users\dmosy\Desktop\ML\df3.csv')

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
# a    500 non-null float64
# b    500 non-null float64
# c    500 non-null float64
# d    500 non-null float64
# dtypes: float64(4)
# memory usage: 15.7 KB

# %%
df3.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %%
df3.plot.scatter(x='a', y='b', figsize=(12,3),s=50, c='r')

# %%
df3['a'].plot.hist(bins=20)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
df3['a'].plot.hist(alpha=0.5)

# %%
df3[['a','b']].boxplot()

# %%
df3['d'].plot.kde(c='r')

# %%
df3['d'].plot.kde(lw=5, ls='--')

# %%
df3.ix[0:30].plot.area(alpha=0.2)

# %%
import matplotlib.pyplot as plt
f = plt.figure()
df3.ix[0:30].plot.area(alpha=0.5)
plt.legend(bbox_to_anchor(1.0, 0.5), loc='best')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-105-5d8381ebd420> in <module>()
#       2 f = plt.figure()
#       3 df3.ix[0:30].plot.area(alpha=0.5)
# ----> 4 plt.legend(bbox_to_anchor(1.0, 0.5), loc='best')
#       5 plt.show()
#
# NameError: name 'bbox_to_anchor' is not defined
